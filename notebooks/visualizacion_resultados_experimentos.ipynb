# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Librerías importadas correctamente.")
# Out:
# Librerías importadas correctamente.

# %%
df_resultados = pd.DataFrame({'x': datos, 'x^2': resultados})
df_resultados.to_csv('resultados_cuadrado.csv', index=False)
print('Archivo resultados_cuadrado.csv guardado correctamente.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_resultados = pd.DataFrame({'x': datos, 'x^2': resultados})
#       2 df_resultados.to_csv('resultados_cuadrado.csv', index=False)
#       3 print('Archivo resultados_cuadrado.csv guardado correctamente.')
#
# NameError: name 'datos' is not defined

# %% [markdown]
# ## 4. Guardar resultados en un archivo
#
# Guardamos los resultados generados en un archivo CSV usando pandas.

# %%
plt.figure(figsize=(8, 4))
plt.plot(datos, resultados, marker='o', linestyle='-', color='b', label='x^2')
plt.title('Ejemplo de visualización: cuadrado de x')
plt.xlabel('x')
plt.ylabel('x^2')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 plt.figure(figsize=(8, 4))
# ----> 2 plt.plot(datos, resultados, marker='o', linestyle='-', color='b', label='x^2')
#       3 plt.title('Ejemplo de visualización: cuadrado de x')
#       4 plt.xlabel('x')
#
# NameError: name 'datos' is not defined

# %% [markdown]
# ## 3. Visualizar resultados con matplotlib
#
# Graficamos los resultados de la función personalizada.

# %%
def cuadrado(x):
    """Devuelve el cuadrado de x."""
    return x ** 2

# Ejemplo de uso
datos = np.arange(1, 11)
resultados = cuadrado(datos)
print("Resultados:", resultados)

# %% [markdown]
# ## 2. Definir una función personalizada
#
# Ejemplo: función para calcular el cuadrado de un número.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Librerías importadas correctamente.")

# %% [markdown]
# ## 1. Importar librerías necesarias
#
# Importamos las librerías más comunes para análisis y visualización de datos en Python.

# %% [markdown]
# # Visualización de Resultados Experimentales
#
# Este notebook contiene ejemplos de visualización y análisis de resultados para experimentos de scheduling. Incluye:
# - Importación de librerías
# - Función personalizada de ejemplo
# - Gráfica sencilla con matplotlib
# - Guardado de resultados en CSV
#
# Puedes adaptar cada sección para tus propios datos y experimentos.
